# %% [markdown]
# # Setup

# %%
# !pip install scipy==1.12.0
# !pip install parallel-wavegan

# %%
# !git clone https://github.com/MahtaFetrat/Persian-MultiSpeaker-Tacotron2.git
# !git clone https://huggingface.co/MahtaFetrat/Persian-Tacotron2-on-ManaTTS
# Out:
# Cloning into 'Persian-MultiSpeaker-Tacotron2'...
# remote: Enumerating objects: 538, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 538 (delta 50), reused 44 (delta 37), pack-reused 473 (from 1)
# Receiving objects: 100% (538/538), 81.71 MiB | 30.56 MiB/s, done.
# Resolving deltas: 100% (168/168), done.
# Cloning into 'Persian-Tacotron2-on-ManaTTS'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 71 (delta 16), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (71/71), 161.58 KiB | 4.62 MiB/s, done.

# %%
# !mkdir /content/Persian-MultiSpeaker-Tacotron2/saved_models/final_models
# !cp /content/Persian-MultiSpeaker-Tacotron2/saved_models/default/encoder.pt /content/Persian-MultiSpeaker-Tacotron2/saved_models/final_models/encoder.pt

# %%
from parallel_wavegan.utils import download_pretrained_model
download_pretrained_model("vctk_hifigan.v1", ".")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1oVOC4Vf0DYLdDp4r7GChfgj7Xh5xd0ex
# From (redirected): https://drive.google.com/uc?id=1oVOC4Vf0DYLdDp4r7GChfgj7Xh5xd0ex&confirm=t&uuid=3b842229-0fdd-4c57-bf33-3c8528810490
# To: /content/vctk_hifigan.v1.tar.gz
# 100%|██████████| 916M/916M [00:12<00:00, 73.7MB/s]
# './vctk_hifigan.v1/checkpoint-2500000steps.pkl'

# %%
# !mv /content/vctk_hifigan.v1/checkpoint-2500000steps.pkl /content/Persian-MultiSpeaker-Tacotron2/saved_models/final_models/vocoder_HiFiGAN.pkl
# !mv /content/vctk_hifigan.v1/config.yml /content/Persian-MultiSpeaker-Tacotron2/saved_models/final_models/config.yml
# !rm -r /content/vctk_hifigan.v1 /content/vctk_hifigan.v1.tar.gz /content/vctk_hifigan.v1.tar.gz.lock
# !mv /content/Persian-Tacotron2-on-ManaTTS/synthesizer.pt /content/Persian-MultiSpeaker-Tacotron2/saved_models/final_models/
# !mkdir /content/Persian-MultiSpeaker-Tacotron2/results

# %% [markdown]
# # Inference

# %%
# !cd /content/Persian-MultiSpeaker-Tacotron2 && python3 inference.py --vocoder "HiFiGAN" --text "مدل تولید گفتار با دادگان نسل مانا" --ref_wav_path "/content/Persian-Tacotron2-on-ManaTTS/sample.wav" --test_name "test_output"
# Out:
# /content/Persian-MultiSpeaker-Tacotron2/encoder/audio.py:13: UserWarning: Unable to import 'webrtcvad'. This package enables noise removal and is recommended.
#   warn("Unable to import 'webrtcvad'. This package enables noise removal and is recommended.")
# /content/Persian-MultiSpeaker-Tacotron2/encoder/inference.py:32: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(weights_fpath, _device)
# Loaded encoder "/content/Persian-MultiSpeaker-Tacotron2/saved_models/final_models/encoder.pt" trained to step 1564501
# Synthesizer using device: cpu
# /usr/local/lib/python3.11/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# /usr/local/lib/python3.11/dist-packages/parallel_wavegan/utils/utils.py:329: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(checkpoint, map_location="cpu")["model"]["generator"]
# Trainable Parameters: 30.901M
# /content/Persian-MultiSpeaker-Tacotron2/synthesizer/models/tacotron.py:496: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(str(path), map_location=device)
# Loaded synthesizer "/content/Persian-MultiSpeaker-Tacotron2/saved_models/final_models/synthesizer.pt" trained to step 300000
#
# | Generating 1/1
#
#
# Done.
#
#
# wav file is saved.

# %%
from IPython.display import Audio
Audio('/content/Persian-MultiSpeaker-Tacotron2/results/test_output.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
